# %%
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.constraints import MaxNorm
from keras.optimizers import SGD
from keras.utils import to_categorical
from keras.optimizers.schedules import ExponentialDecay
import matplotlib.pyplot as plt

# Fix random seed for reproducibility
seed = 7
np.random.seed(seed)

# Load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Normalize inputs from 0-255 to 0.0-1.0
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# One hot encode outputs
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
num_classes = y_test.shape[1]

# Create the model
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

# Compile model
epochs = 50
lrate = 0.01
lr_schedule = ExponentialDecay(
    initial_learning_rate=lrate,
    decay_steps=epochs * len(X_train) // 32,
    decay_rate=0.1
)
sgd = SGD(learning_rate=lr_schedule, momentum=0.9, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
print(model.summary())

# Fit the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=32)

# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1] * 100))

# Predict the first 4 images of the test data
predictions = model.predict(X_test[:4])
predicted_classes = np.argmax(predictions, axis=1)
actual_classes = np.argmax(y_test[:4], axis=1)


# Print the predictions and actual labels
print("Predicted classes: ", predicted_classes)
print("Actual classes: ", actual_classes)

# Plot the first 4 test images, predicted labels, and actual labels
fig, axes = plt.subplots(1, 4, figsize=(15, 3))
for i in range(4):
    axes[i].imshow(X_test[i])
    axes[i].set_title(f"Pred: {predicted_classes[i]}, Actual: {actual_classes[i]}")
    axes[i].axis('off')
# Visualize loss and accuracy
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  dropout_2 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2915114 (11.12 MB)
# Trainable params: 2915114 (11.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 1563/1563 [==============================] - 21s 9ms/step - loss: 1.9477 - accuracy: 0.2808 - val_loss: 1.6736 - val_accuracy: 0.3981
# Epoch 2/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.4790 - accuracy: 0.4592 - val_loss: 1.3330 - val_accuracy: 0.5179
# Epoch 3/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.2455 - accuracy: 0.5533 - val_loss: 1.0849 - val_accuracy: 0.6141
# Epoch 4/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.0654 - accuracy: 0.6208 - val_loss: 1.0205 - val_accuracy: 0.6428
# Epoch 5/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9273 - accuracy: 0.6717 - val_loss: 0.8411 - val_accuracy: 0.7017
# Epoch 6/50
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.8301 - accuracy: 0.7067 - val_loss: 0.8239 - val_accuracy: 0.7075
# Epoch 7/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7533 - accuracy: 0.7356 - val_loss: 0.7486 - val_accuracy: 0.7421
# Epoch 8/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6923 - accuracy: 0.7556 - val_loss: 0.7840 - val_accuracy: 0.7232
# Epoch 9/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6377 - accuracy: 0.7754 - val_loss: 0.6921 - val_accuracy: 0.7593
# Epoch 10/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5853 - accuracy: 0.7933 - val_loss: 0.6804 - val_accuracy: 0.7643
# Epoch 11/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5404 - accuracy: 0.8087 - val_loss: 0.6714 - val_accuracy: 0.7744
# Epoch 12/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5102 - accuracy: 0.8193 - val_loss: 0.6438 - val_accuracy: 0.7851
# Epoch 13/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.4677 - accuracy: 0.8337 - val_loss: 0.6536 - val_accuracy: 0.7785
# Epoch 14/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.4344 - accuracy: 0.8448 - val_loss: 0.6196 - val_accuracy: 0.7972
# Epoch 15/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.4018 - accuracy: 0.8576 - val_loss: 0.6426 - val_accuracy: 0.7859
# Epoch 16/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3732 - accuracy: 0.8677 - val_loss: 0.6214 - val_accuracy: 0.7972
# Epoch 17/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3431 - accuracy: 0.8783 - val_loss: 0.6289 - val_accuracy: 0.8018
# Epoch 18/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3204 - accuracy: 0.8855 - val_loss: 0.6544 - val_accuracy: 0.7917
# Epoch 19/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2961 - accuracy: 0.8946 - val_loss: 0.6304 - val_accuracy: 0.7998
# Epoch 20/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2752 - accuracy: 0.9022 - val_loss: 0.6594 - val_accuracy: 0.8007
# Epoch 21/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2496 - accuracy: 0.9113 - val_loss: 0.6532 - val_accuracy: 0.8063
# Epoch 22/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2343 - accuracy: 0.9161 - val_loss: 0.6331 - val_accuracy: 0.8096
# Epoch 23/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2187 - accuracy: 0.9230 - val_loss: 0.6784 - val_accuracy: 0.8004
# Epoch 24/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2046 - accuracy: 0.9288 - val_loss: 0.6942 - val_accuracy: 0.8074
# Epoch 25/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.1887 - accuracy: 0.9338 - val_loss: 0.7034 - val_accuracy: 0.8001
# Epoch 26/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1719 - accuracy: 0.9386 - val_loss: 0.7065 - val_accuracy: 0.8055
# Epoch 27/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.1618 - accuracy: 0.9434 - val_loss: 0.7224 - val_accuracy: 0.8062
# Epoch 28/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1466 - accuracy: 0.9474 - val_loss: 0.7224 - val_accuracy: 0.8095
# Epoch 29/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1381 - accuracy: 0.9507 - val_loss: 0.7194 - val_accuracy: 0.8143
# Epoch 30/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1285 - accuracy: 0.9548 - val_loss: 0.7306 - val_accuracy: 0.8148
# Epoch 31/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1236 - accuracy: 0.9574 - val_loss: 0.7391 - val_accuracy: 0.8147
# Epoch 32/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1130 - accuracy: 0.9611 - val_loss: 0.7524 - val_accuracy: 0.8143
# Epoch 33/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1083 - accuracy: 0.9625 - val_loss: 0.7696 - val_accuracy: 0.8138
# Epoch 34/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1003 - accuracy: 0.9646 - val_loss: 0.7609 - val_accuracy: 0.8171
# Epoch 35/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0965 - accuracy: 0.9672 - val_loss: 0.7666 - val_accuracy: 0.8188
# Epoch 36/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.0896 - accuracy: 0.9688 - val_loss: 0.7817 - val_accuracy: 0.8175
# Epoch 37/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0800 - accuracy: 0.9718 - val_loss: 0.7636 - val_accuracy: 0.8206
# Epoch 38/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0791 - accuracy: 0.9728 - val_loss: 0.7830 - val_accuracy: 0.8216
# Epoch 39/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0756 - accuracy: 0.9736 - val_loss: 0.7922 - val_accuracy: 0.8174
# Epoch 40/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0706 - accuracy: 0.9751 - val_loss: 0.7985 - val_accuracy: 0.8177
# Epoch 41/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.0701 - accuracy: 0.9764 - val_loss: 0.7817 - val_accuracy: 0.8208
# Epoch 42/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0646 - accuracy: 0.9778 - val_loss: 0.8005 - val_accuracy: 0.8207
# Epoch 43/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0654 - accuracy: 0.9768 - val_loss: 0.8065 - val_accuracy: 0.8203
# Epoch 44/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0606 - accuracy: 0.9786 - val_loss: 0.7935 - val_accuracy: 0.8241
# Epoch 45/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0575 - accuracy: 0.9798 - val_loss: 0.8178 - val_accuracy: 0.8238
# Epoch 46/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0537 - accuracy: 0.9812 - val_loss: 0.8501 - val_accuracy: 0.8202
# Epoch 47/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.0537 - accuracy: 0.9815 - val_loss: 0.8220 - val_accuracy: 0.8222
# Epoch 48/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.0509 - accuracy: 0.9825 - val_loss: 0.8425 - val_accuracy: 0.8256
# Epoch 49/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0463 - accuracy: 0.9840 - val_loss: 0.8651 - val_accuracy: 0.8236
# Epoch 50/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0476 - accuracy: 0.9836 - val_loss: 0.8530 - val_accuracy: 0.8241
# Accuracy: 82.41%
# 1/1 [==============================] - 0s 369ms/step
# Predicted classes:  [3 8 0 0]
# Actual classes:  [3 8 8 0]
